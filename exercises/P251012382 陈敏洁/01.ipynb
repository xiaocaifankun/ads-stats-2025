# %%
print('hi')
# Out:
# hi

# %%
a1=00
print(type(a1))
# Out:
# <class 'float'>

# %%
a2=100
print(type(a2))
# Out:
# <class 'int'>

# %%
a3='听说你们今晚有课'
print(type(a3))
# Out:
# <class 'str'>

# %%
a4=True
print(type(a4))
# Out:
# <class 'bool'>

# %%
a5=None
print(type(a5))
# Out:
# <class 'NoneType'>

# %%
a6=[25,26,27]
print(type(a6))
# Out:
# <class 'list'>

# %%
a7=(24,25,26)
print(type(a7))
# Out:
# <class 'tuple'>

# %%
print(round(0.1+0.2,1) ==0.3)
# Out:
# True

# %%
print(False or True)
# Out:
# True

# %%
print(not False)
# Out:
# True

# %%
( False and True)  and ( True or False)
# Out:
# False

# %%
channels = {"抖音","微信","小红书"}
"视频号" not in channels
# Out:
# True

# %%
age = 16

if age >= 18:
    print("你已经成年了")
elif age >=16:
    print("小心，可以判刑了")
else:
    print("你还未成年")
# Out:
# 小心，可以判刑了

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
hungry = 100
while hungry > 0:
    print("我会一直吃下去，直到吃饱为止")
    print("我在干饭，饥饿感为：",hungry)
    hungry -= 10
# Out:
# 我会一直吃下去，直到吃饱为止
# 我在干饭，饥饿感为： 100
# 我会一直吃下去，直到吃饱为止
# 我在干饭，饥饿感为： 90
# 我会一直吃下去，直到吃饱为止
# 我在干饭，饥饿感为： 80
# 我会一直吃下去，直到吃饱为止
# 我在干饭，饥饿感为： 70
# 我会一直吃下去，直到吃饱为止
# 我在干饭，饥饿感为： 60
# 我会一直吃下去，直到吃饱为止
# 我在干饭，饥饿感为： 50
# 我会一直吃下去，直到吃饱为止
# 我在干饭，饥饿感为： 40
# 我会一直吃下去，直到吃饱为止
# 我在干饭，饥饿感为： 30
# 我会一直吃下去，直到吃饱为止
# 我在干饭，饥饿感为： 20
# 我会一直吃下去，直到吃饱为止
# 我在干饭，饥饿感为： 10
